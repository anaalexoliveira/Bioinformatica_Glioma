# %%
import pandas as pd

# %% [markdown]
# ## Dataset 3

# %% [markdown]
# ### Leitura dos dados

# %%
data_glioma = pd.read_csv("data_RNA_Seq_v2_expression_median.txt", sep='\t', index_col = 0)

# %%
data_glioma.shape
# Out:
# (20531, 531)

# %%
data_glioma.head()
# Out:
#               Entrez_Gene_Id  TCGA-CS-4938-01  TCGA-CS-4941-01  \
# Hugo_Symbol
# LOC100130426       100130426           0.0000           0.0000
# UBE2Q2P3           100133144           8.7141          36.4493
# UBE2Q2P3           100134869          22.7523          21.1767
# LOC149767              10357         268.5756         156.6874
# TIMM23                 10431         845.8150         390.2692
#
#               TCGA-CS-4942-01  TCGA-CS-4943-01  TCGA-CS-4944-01  \
# Hugo_Symbol
# LOC100130426           0.0000           0.0000           0.0000
# UBE2Q2P3              11.8131           8.6116           0.0000
# UBE2Q2P3              11.0242           5.0835          30.2610
# LOC149767            185.1384         269.8363         216.3409
# TIMM23               621.4533         835.7286         812.5079
#
#               TCGA-CS-5390-01  TCGA-CS-5393-01  TCGA-CS-5394-01  \
# Hugo_Symbol
# LOC100130426           0.0000           0.0000           0.0000
# UBE2Q2P3               5.3382           3.7845           8.3071
# UBE2Q2P3              27.8886           8.7230          15.4466
# LOC149767            159.7590         198.1884         208.5413
# TIMM23               576.9055         551.9467         607.8956
#
#               TCGA-CS-5395-01  ...  TCGA-VW-A8FI-01  TCGA-W9-A837-01  \
# Hugo_Symbol                    ...
# LOC100130426           0.0000  ...           0.0000           0.0000
# UBE2Q2P3               2.7732  ...          19.1299          12.5770
# UBE2Q2P3              12.7776  ...          21.9905          27.0125
# LOC149767            255.2882  ...         127.7473         106.8292
# TIMM23               386.1776  ...         564.3623         603.3724
#
#               TCGA-WH-A86K-01  TCGA-WY-A858-01  TCGA-WY-A859-01  \
# Hugo_Symbol
# LOC100130426           0.0000           0.0000           0.0000
# UBE2Q2P3              10.9796           7.8225           3.3371
# UBE2Q2P3              14.2608          16.6975          10.2310
# LOC149767            205.5168         184.4077         125.5468
# TIMM23               570.9135         760.7155         875.1413
#
#               TCGA-WY-A85A-01  TCGA-WY-A85B-01  TCGA-WY-A85C-01  \
# Hugo_Symbol
# LOC100130426           0.0000           0.0000           0.0000
# UBE2Q2P3               5.4526           8.2616          11.5121
# UBE2Q2P3              16.1890          19.7074          18.7291
# LOC149767            124.9195         133.7392         120.9236
# TIMM23               658.2212         662.6506         524.7242
#
#               TCGA-WY-A85D-01  TCGA-WY-A85E-01
# Hugo_Symbol
# LOC100130426           0.0000           0.0000
# UBE2Q2P3               5.3895           9.9433
# UBE2Q2P3               8.9103           7.4480
# LOC149767            107.2535         143.0057
# TIMM23               705.1282         748.5822
#
# [5 rows x 531 columns]

# %%
del data_glioma["Entrez_Gene_Id"]

# %%
data_glioma.shape  ## 20531 genes x 530 amostras
# Out:
# (20531, 530)

# %% [markdown]
# ### Metadados

# %%
clinical_patient_data = pd.read_csv("data_bcr_clinical_data_patient.txt", sep='\t', index_col = 1)
clinical_sample_data = pd.read_csv("data_bcr_clinical_data_sample.txt", sep='\t', index_col = 1)

# %%
clinical_patient_data.columns = clinical_patient_data.iloc[3].values
clinical_patient_data = clinical_patient_data[4:]
clinical_patient_data.head()
# Out:
#                                         OTHER_PATIENT_ID FORM_COMPLETION_DATE  \
# Patient Identifier
# TCGA-CS-4938        334f715e-08dc-4a29-b8e4-b010b829c478              2/15/12
# TCGA-CS-4941        fc222f23-b3b2-4ac0-bc61-e8e8fa5cc160               4/5/11
# TCGA-CS-4942        230f5fa7-aa36-41ea-b40b-08f520767bd5              3/15/11
# TCGA-CS-4943        952dfd5d-e65a-4307-b6a9-2ed2b0d2d9ce              3/16/11
# TCGA-CS-4944        64cd17eb-c778-45e9-b994-02b68182e51b               4/6/11
#
#                    HISTOLOGICAL_DIAGNOSIS GRADE LATERALITY  \
# Patient Identifier
# TCGA-CS-4938                  Astrocytoma    G2      Right
# TCGA-CS-4941                  Astrocytoma    G3      Right
# TCGA-CS-4942                  Astrocytoma    G3      Right
# TCGA-CS-4943                  Astrocytoma    G3       Left
# TCGA-CS-4944                  Astrocytoma    G2      Right
#
#                                        TUMOR_SITE SUPRATENTORIAL_LOCALIZATION  \
# Patient Identifier
# TCGA-CS-4938         Supratentorial, Frontal Lobe             Cerebral Cortex
# TCGA-CS-4941         Supratentorial, Frontal Lobe             Cerebral Cortex
# TCGA-CS-4942         Supratentorial, Frontal Lobe                White Matter
# TCGA-CS-4943         Supratentorial, Frontal Lobe             Cerebral Cortex
# TCGA-CS-4944        Supratentorial, Temporal Lobe             Cerebral Cortex
#
#                    PROSPECTIVE_COLLECTION RETROSPECTIVE_COLLECTION     SEX  \
# Patient Identifier
# TCGA-CS-4938                           NO                      YES  Female
# TCGA-CS-4941                           NO                      YES    Male
# TCGA-CS-4942                           NO                      YES  Female
# TCGA-CS-4943                           NO                      YES    Male
# TCGA-CS-4944                           NO                      YES    Male
#
#                     ... ICD_O_3_SITE INFORMED_CONSENT_VERIFIED  \
# Patient Identifier  ...
# TCGA-CS-4938        ...        C71.9                       YES
# TCGA-CS-4941        ...        C71.9                       YES
# TCGA-CS-4942        ...        C71.9                       YES
# TCGA-CS-4943        ...        C71.9                       YES
# TCGA-CS-4944        ...        C71.9                       YES
#
#                        PROJECT_CODE TARGETED_MOLECULAR_THERAPY  \
# Patient Identifier
# TCGA-CS-4938        [Not Available]            [Not Available]
# TCGA-CS-4941        [Not Available]            [Not Available]
# TCGA-CS-4942        [Not Available]            [Not Available]
# TCGA-CS-4943        [Not Available]            [Not Available]
# TCGA-CS-4944        [Not Available]            [Not Available]
#
#                    TISSUE_SOURCE_SITE    SITE_OF_TUMOR_TISSUE OS_STATUS  \
# Patient Identifier
# TCGA-CS-4938                       CS  Central nervous system    LIVING
# TCGA-CS-4941                       CS  Central nervous system  DECEASED
# TCGA-CS-4942                       CS  Central nervous system  DECEASED
# TCGA-CS-4943                       CS  Central nervous system  DECEASED
# TCGA-CS-4944                       CS  Central nervous system    LIVING
#
#                    OS_MONTHS           DFS_STATUS       DFS_MONTHS
# Patient Identifier
# TCGA-CS-4938          117.41          DiseaseFree           117.41
# TCGA-CS-4941            7.69  Recurred/Progressed              0.3
# TCGA-CS-4942           43.86  Recurred/Progressed             38.9
# TCGA-CS-4943           36.33      [Not Available]  [Not Available]
# TCGA-CS-4944           60.05          DiseaseFree            60.05
#
# [5 rows x 67 columns]

# %%
clinical_patient_data.shape
# Out:
# (515, 67)

# %%
clinical_patient_data.describe()
# Out:
#                             OTHER_PATIENT_ID FORM_COMPLETION_DATE  \
# count                                    515                  515
# unique                                   515                  171
# top     334f715e-08dc-4a29-b8e4-b010b829c478             11/13/14
# freq                                       1                   14
#
#        HISTOLOGICAL_DIAGNOSIS GRADE LATERALITY                    TUMOR_SITE  \
# count                     515   515        515                           515
# unique                      3     3          4                             8
# top               Astrocytoma    G3      Right  Supratentorial, Frontal Lobe
# freq                      194   265        253                           302
#
#          SUPRATENTORIAL_LOCALIZATION PROSPECTIVE_COLLECTION  \
# count                            515                    515
# unique                             5                      3
# top     Not listed in Medical Record                     NO
# freq                             222                    331
#
#        RETROSPECTIVE_COLLECTION   SEX  ... ICD_O_3_SITE  \
# count                       515   515  ...          515
# unique                        3     2  ...            6
# top                         YES  Male  ...        C71.0
# freq                        330   285  ...          439
#
#        INFORMED_CONSENT_VERIFIED     PROJECT_CODE TARGETED_MOLECULAR_THERAPY  \
# count                        515              515                        515
# unique                         1                1                          3
# top                          YES  [Not Available]            [Not Available]
# freq                         515              515                        251
#
#        TISSUE_SOURCE_SITE    SITE_OF_TUMOR_TISSUE OS_STATUS OS_MONTHS  \
# count                 515                     515       515       515
# unique                 26                       1         2       434
# top                    HT  Central nervous system    LIVING       0.1
# freq                  104                     515       389         9
#
#          DFS_STATUS       DFS_MONTHS
# count           515              515
# unique            3              404
# top     DiseaseFree  [Not Available]
# freq            313               37
#
# [4 rows x 67 columns]

# %%
clinical_sample_data.columns = clinical_sample_data.iloc[3].values
clinical_sample_data = clinical_sample_data[4:]

clinical_sample_data.head()
# Out:
#                      PATIENT_ID                       OTHER_SAMPLE_ID  \
# Sample Identifier
# TCGA-CS-6290-01    TCGA-CS-6290  6148f31e-cdba-481b-bcd7-b3aee05925b1
# TCGA-DU-5847-01    TCGA-DU-5847  c68fc12c-c538-4a89-9f6e-c0800a5a6b53
# TCGA-DU-5849-01    TCGA-DU-5849  9e0e239f-ced4-4cf3-bf3c-5ec8224d760b
# TCGA-DU-5852-01    TCGA-DU-5852  101aaa90-fe0a-42b7-bcc7-4f44e29883ec
# TCGA-DU-5854-01    TCGA-DU-5854  d5baa53a-958c-4163-a388-d3c957c891f9
#
#                   SPECIMEN_CURRENT_WEIGHT DAYS_TO_COLLECTION  \
# Sample Identifier
# TCGA-CS-6290-01           [Not Available]    [Not Available]
# TCGA-DU-5847-01           [Not Available]    [Not Available]
# TCGA-DU-5849-01           [Not Available]    [Not Available]
# TCGA-DU-5852-01           [Not Available]    [Not Available]
# TCGA-DU-5854-01           [Not Available]    [Not Available]
#
#                   DAYS_TO_SPECIMEN_COLLECTION SPECIMEN_FREEZING_METHOD  \
# Sample Identifier
# TCGA-CS-6290-01               [Not Available]          [Not Available]
# TCGA-DU-5847-01               [Not Available]          [Not Available]
# TCGA-DU-5849-01               [Not Available]          [Not Available]
# TCGA-DU-5852-01               [Not Available]          [Not Available]
# TCGA-DU-5854-01               [Not Available]          [Not Available]
#
#                   SAMPLE_INITIAL_WEIGHT SPECIMEN_SECOND_LONGEST_DIMENSION  \
# Sample Identifier
# TCGA-CS-6290-01         [Not Available]                               0.4
# TCGA-DU-5847-01         [Not Available]                               0.8
# TCGA-DU-5849-01         [Not Available]                               0.9
# TCGA-DU-5852-01         [Not Available]                               0.9
# TCGA-DU-5854-01         [Not Available]                               0.9
#
#                   IS_FFPE LONGEST_DIMENSION  ...  \
# Sample Identifier                            ...
# TCGA-CS-6290-01        NO               0.4  ...
# TCGA-DU-5847-01        NO                 1  ...
# TCGA-DU-5849-01        NO               0.9  ...
# TCGA-DU-5852-01        NO                 1  ...
# TCGA-DU-5854-01        NO                 1  ...
#
#                                   PATHOLOGY_REPORT_UUID SAMPLE_TYPE  \
# Sample Identifier
# TCGA-CS-6290-01    4d5bdf18-7799-463d-a33a-beb8322b0621     Primary
# TCGA-DU-5847-01    d9f2d994-5d17-46c6-a6c9-0f25703ffb22     Primary
# TCGA-DU-5849-01    7ec64754-8800-44dd-a5cc-2a9e8fc8bb27     Primary
# TCGA-DU-5852-01    a6c1f30a-8350-4fbc-9af2-5333cbe273e6     Primary
# TCGA-DU-5854-01    e057679f-9741-4a4e-bb60-e03879b1c723     Primary
#
#                   SAMPLE_TYPE_ID SHORTEST_DIMENSION  \
# Sample Identifier
# TCGA-CS-6290-01                1                0.4
# TCGA-DU-5847-01                1                0.4
# TCGA-DU-5849-01                1                0.4
# TCGA-DU-5852-01                1                0.9
# TCGA-DU-5854-01                1                0.7
#
#                   TIME_BETWEEN_CLAMPING_AND_FREEZING  \
# Sample Identifier
# TCGA-CS-6290-01                      [Not Available]
# TCGA-DU-5847-01                      [Not Available]
# TCGA-DU-5849-01                      [Not Available]
# TCGA-DU-5852-01                      [Not Available]
# TCGA-DU-5854-01                      [Not Available]
#
#                   TIME_BETWEEN_EXCISION_AND_FREEZING VIAL_NUMBER  \
# Sample Identifier
# TCGA-CS-6290-01                      [Not Available]           A
# TCGA-DU-5847-01                      [Not Available]           A
# TCGA-DU-5849-01                      [Not Available]           A
# TCGA-DU-5852-01                      [Not Available]           A
# TCGA-DU-5854-01                      [Not Available]           A
#
#                   ONCOTREE_CODE CANCER_TYPE    CANCER_TYPE_DETAILED
# Sample Identifier
# TCGA-CS-6290-01           AASTR      Glioma  Anaplastic Astrocytoma
# TCGA-DU-5847-01           AASTR      Glioma  Anaplastic Astrocytoma
# TCGA-DU-5849-01             ODG      Glioma       Oligodendroglioma
# TCGA-DU-5852-01            OAST      Glioma        Oligoastrocytoma
# TCGA-DU-5854-01           AASTR      Glioma  Anaplastic Astrocytoma
#
# [5 rows x 24 columns]

# %%
clinical_sample_data.shape
# Out:
# (530, 24)

# %%
(clinical_sample_data.index.sort_values() == data_glioma.columns.sort_values()).sum()
# Out:
# 530

# %%
clinical_sample_data["PATIENT_ID"].sort_values()
# Out:
# Sample Identifier
# TCGA-CS-4938-01    TCGA-CS-4938
# TCGA-CS-4941-01    TCGA-CS-4941
# TCGA-CS-4942-01    TCGA-CS-4942
# TCGA-CS-4943-01    TCGA-CS-4943
# TCGA-CS-4944-01    TCGA-CS-4944
#                        ...
# TCGA-WY-A85A-01    TCGA-WY-A85A
# TCGA-WY-A85B-01    TCGA-WY-A85B
# TCGA-WY-A85C-01    TCGA-WY-A85C
# TCGA-WY-A85D-01    TCGA-WY-A85D
# TCGA-WY-A85E-01    TCGA-WY-A85E
# Name: PATIENT_ID, Length: 530, dtype: object

# %%
clinical_patient_data.index.sort_values()
# Out:
# Index(['TCGA-CS-4938', 'TCGA-CS-4941', 'TCGA-CS-4942', 'TCGA-CS-4943',
#        'TCGA-CS-4944', 'TCGA-CS-5390', 'TCGA-CS-5393', 'TCGA-CS-5394',
#        'TCGA-CS-5395', 'TCGA-CS-5396',
#        ...
#        'TCGA-VW-A8FI', 'TCGA-W9-A837', 'TCGA-WH-A86K', 'TCGA-WY-A858',
#        'TCGA-WY-A859', 'TCGA-WY-A85A', 'TCGA-WY-A85B', 'TCGA-WY-A85C',
#        'TCGA-WY-A85D', 'TCGA-WY-A85E'],
#       dtype='object', name='Patient Identifier', length=515)

# %%
unified_meta = clinical_sample_data.join(clinical_patient_data, on = "PATIENT_ID")

# %%
unified_meta.shape
# Out:
# (530, 91)

# %%
unified_meta.head() ## metadados juntando os dois data frames; notem que ha pacientes repetidos
# Out:
#                      PATIENT_ID                       OTHER_SAMPLE_ID  \
# Sample Identifier
# TCGA-CS-6290-01    TCGA-CS-6290  6148f31e-cdba-481b-bcd7-b3aee05925b1
# TCGA-DU-5847-01    TCGA-DU-5847  c68fc12c-c538-4a89-9f6e-c0800a5a6b53
# TCGA-DU-5849-01    TCGA-DU-5849  9e0e239f-ced4-4cf3-bf3c-5ec8224d760b
# TCGA-DU-5852-01    TCGA-DU-5852  101aaa90-fe0a-42b7-bcc7-4f44e29883ec
# TCGA-DU-5854-01    TCGA-DU-5854  d5baa53a-958c-4163-a388-d3c957c891f9
#
#                   SPECIMEN_CURRENT_WEIGHT DAYS_TO_COLLECTION  \
# Sample Identifier
# TCGA-CS-6290-01           [Not Available]    [Not Available]
# TCGA-DU-5847-01           [Not Available]    [Not Available]
# TCGA-DU-5849-01           [Not Available]    [Not Available]
# TCGA-DU-5852-01           [Not Available]    [Not Available]
# TCGA-DU-5854-01           [Not Available]    [Not Available]
#
#                   DAYS_TO_SPECIMEN_COLLECTION SPECIMEN_FREEZING_METHOD  \
# Sample Identifier
# TCGA-CS-6290-01               [Not Available]          [Not Available]
# TCGA-DU-5847-01               [Not Available]          [Not Available]
# TCGA-DU-5849-01               [Not Available]          [Not Available]
# TCGA-DU-5852-01               [Not Available]          [Not Available]
# TCGA-DU-5854-01               [Not Available]          [Not Available]
#
#                   SAMPLE_INITIAL_WEIGHT SPECIMEN_SECOND_LONGEST_DIMENSION  \
# Sample Identifier
# TCGA-CS-6290-01         [Not Available]                               0.4
# TCGA-DU-5847-01         [Not Available]                               0.8
# TCGA-DU-5849-01         [Not Available]                               0.9
# TCGA-DU-5852-01         [Not Available]                               0.9
# TCGA-DU-5854-01         [Not Available]                               0.9
#
#                   IS_FFPE LONGEST_DIMENSION  ... ICD_O_3_SITE  \
# Sample Identifier                            ...
# TCGA-CS-6290-01        NO               0.4  ...        C71.9
# TCGA-DU-5847-01        NO                 1  ...        C71.9
# TCGA-DU-5849-01        NO               0.9  ...        C71.9
# TCGA-DU-5852-01        NO                 1  ...        C71.9
# TCGA-DU-5854-01        NO                 1  ...        C71.9
#
#                   INFORMED_CONSENT_VERIFIED     PROJECT_CODE  \
# Sample Identifier
# TCGA-CS-6290-01                         YES  [Not Available]
# TCGA-DU-5847-01                         YES  [Not Available]
# TCGA-DU-5849-01                         YES  [Not Available]
# TCGA-DU-5852-01                         YES  [Not Available]
# TCGA-DU-5854-01                         YES  [Not Available]
#
#                   TARGETED_MOLECULAR_THERAPY TISSUE_SOURCE_SITE  \
# Sample Identifier
# TCGA-CS-6290-01              [Not Available]                 CS
# TCGA-DU-5847-01              [Not Available]                 DU
# TCGA-DU-5849-01              [Not Available]                 DU
# TCGA-DU-5852-01              [Not Available]                 DU
# TCGA-DU-5854-01              [Not Available]                 DU
#
#                      SITE_OF_TUMOR_TISSUE OS_STATUS OS_MONTHS  \
# Sample Identifier
# TCGA-CS-6290-01    Central nervous system  DECEASED     37.35
# TCGA-DU-5847-01    Central nervous system    LIVING        18
# TCGA-DU-5849-01    Central nervous system    LIVING     14.55
# TCGA-DU-5852-01    Central nervous system  DECEASED      6.73
# TCGA-DU-5854-01    Central nervous system    LIVING      8.44
#
#                             DFS_STATUS       DFS_MONTHS
# Sample Identifier
# TCGA-CS-6290-01        [Not Available]  [Not Available]
# TCGA-DU-5847-01            DiseaseFree               18
# TCGA-DU-5849-01            DiseaseFree            14.55
# TCGA-DU-5852-01    Recurred/Progressed             0.79
# TCGA-DU-5854-01    Recurred/Progressed             6.64
#
# [5 rows x 91 columns]

# %%
unified_meta.describe()
# Out:
#           PATIENT_ID                       OTHER_SAMPLE_ID  \
# count            530                                   530
# unique           516                                   530
# top     TCGA-FG-A4MT  6148f31e-cdba-481b-bcd7-b3aee05925b1
# freq               2                                     1
#
#        SPECIMEN_CURRENT_WEIGHT DAYS_TO_COLLECTION DAYS_TO_SPECIMEN_COLLECTION  \
# count                      530                530                         530
# unique                       1                267                           1
# top            [Not Available]    [Not Available]             [Not Available]
# freq                       530                223                         530
#
#        SPECIMEN_FREEZING_METHOD SAMPLE_INITIAL_WEIGHT  \
# count                       530                   530
# unique                        1                    61
# top             [Not Available]       [Not Available]
# freq                        530                   223
#
#        SPECIMEN_SECOND_LONGEST_DIMENSION IS_FFPE LONGEST_DIMENSION  ...  \
# count                                530     530               530  ...
# unique                                16       1                29  ...
# top                      [Not Available]      NO   [Not Available]  ...
# freq                                 308     530               308  ...
#
#        ICD_O_3_SITE INFORMED_CONSENT_VERIFIED     PROJECT_CODE  \
# count           529                       529              529
# unique            6                         1                1
# top           C71.0                       YES  [Not Available]
# freq            450                       529              529
#
#        TARGETED_MOLECULAR_THERAPY TISSUE_SOURCE_SITE    SITE_OF_TUMOR_TISSUE  \
# count                         529                529                     529
# unique                          3                 26                       1
# top               [Not Available]                 HT  Central nervous system
# freq                          259                104                     529
#
#        OS_STATUS OS_MONTHS   DFS_STATUS       DFS_MONTHS
# count        529       529          529              529
# unique         2       434            3              404
# top       LIVING       0.1  DiseaseFree  [Not Available]
# freq         395         9          313               37
#
# [4 rows x 91 columns]
